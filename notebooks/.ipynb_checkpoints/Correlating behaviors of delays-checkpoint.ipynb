# %% [markdown]
# *August 8, 2018*
#
# In the notebook of *"Manual Classification of delays"* I identified some figures, for example the following ones:
#
# -----
#
# ### Gaussian-Like behavior
#
# There is a *mean* and a *std* that could describe the major part of the data, as shown in this example
#
# ![gaussian-like.png](attachment:gaussian-like.png)
#
# -----
#
# ### Leftist density
#
# The processes between (a,b) takes a pretty constant amount of time, except by a small set of points spread evenly up to certain amount of extra delay.
#
# ![leftist.png](attachment:leftist.png)
#
# -----
#
# ### Pulse behavior, < 10ms
#
# For practical purposes, all delays below a certain threshold, for example 10ms, could be thought as instantaneous.
#
# ![pulse-behavior.png](attachment:pulse-behavior.png)
#
# -----
#
# ### Composed behavior
#
# This is a bit harder to understand, but in general one could think in adding two or more of the previous groups of behaviors.
#
# ![composed-behavior-A.png](attachment:composed-behavior-A.png)
#
# ![composed-behavior-B.png](attachment:composed-behavior-B.png)
#
# -----
#
# ## Pre processing
#
# Given a set of delays from a set of cases previously computed, I applied another two pre-processing techniques:
#
# 1. Filter out sets with few samples, by manually setting the parameter *MIN_NUMBER_OF_SAMPLES* arbitrarily to 100
# 2. Use a light criteria for outlier remotion, just leaving in the set data between +-3 sigma of the mean.
#
# I'm not assuming a Gaussian distribution, but using that criteria to quickly remove very far points that would add innecessary noise to the found histograms.
#
# # Correlating gaussian and lognormal shape
#
# Let's work with the example of (465, 476) as seen in the first example above. Let's set up our Python environment first:

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from src import *
from src.models.AlmaClasses import *
palette = PaletteFileDB(filename='../data/processed/colors-almaAntenna.pkl', colorFunction=paintedForAlmaAntennas )
colors=palette.getColors()
db = DelaysFileDB( caseName="CaseAntennaObserving", path= '../' + config.FILEPATH_DB+"/delays") 

# %matplotlib inline
from pandas import Series

from matplotlib import pyplot
import matplotlib.pyplot as plt

import numpy as np
import scipy.stats

pyplot.rcParams["figure.figsize"] = (22,6)

# %%
# Function to remove possible outliers, up to sigma = 3
def remove_outliers(dataset, sigma=3):
    mean = np.mean(dataset, axis=0)
    sd = np.std(dataset, axis=0)
    return [ x for x in dataset if (x >= mean - 3.0 * sd) and (x <= mean + 3.0 * sd) ]

# %%
# This is my pair of interest, a Gaussian-like shape
a, b = 465, 476

for (a,b) in [ (465, 476), (464, 484), (494,505) ]:

    print "{{color %s}} %s" % (a, colors[a])
    print "{{color %s}} %s" % (b, colors[b])
    s = remove_outliers( db.getDelays(a,b) )

    plt.plot(sorted(s))
    plt.title( "Color: (%s, %s)" % (a,b) )
    plt.show()

    print Series(s).describe()

    plt.hist(s, bins=25, density=True, alpha=0.6, color='g')

    # Fit a normal distribution to the data:
    mu, std = scipy.stats.norm.fit(s)

    # Plot the PDF.99
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 100)
    p = scipy.stats.norm.pdf(x, mu, std)
    plt.plot(x, p, 'k', linewidth=2, color='#555555')

    # Fit a lognormal distribution
    shape, loc, scale = scipy.stats.lognorm.fit(s, loc=0)
    print shape, loc, scale
    p2 = scipy.stats.lognorm.pdf(x, shape, loc=loc, scale=scale )
    plt.plot(x, p2, linewidth=2, color='r')
    plt.title("GREEN: Actual distribution. GRAY: Gaussian fitting attempt. RED: Lognormal fitting attempt.")
    plt.show()
    
    print;print;print
# Out:
# {{color 465}} [maci::LibraryManager - maci::LibraryManager::load] Full path '${PATH}/libAntInterferometryController.so'
# {{color 476}} [CONTROL/${ANT}/cppContainer-GL - ] Switched state of component CONTROL/${ANT}/TOTALPOWER: NEW -> INITIALIZING
# count      335.000000
# mean     19983.659701
# std       3672.374285
# min       9505.000000
# 25%      18091.500000
# 50%      19087.000000
# 75%      21362.000000
# max      31305.000000
# dtype: float64
# 0.17071928733906053 -917.1965838390497 20595.70603976163
# {{color 464}} [maci::LibraryManager - maci::LibraryManager::load] Request to load 'AntInterferometryController'.
# {{color 484}} [CONTROL/${ANT}/IFProc_B - beginDataAcquisition] Data acquisition activated.
# count      332.000000
# mean     21167.707831
# std       3609.839342
# min      11496.000000
# 25%      19536.000000
# 50%      20654.500000
# 75%      22232.000000
# max      31910.000000
# dtype: float64
# 0.10598018976368936 -12589.124283982363 33548.80255767461
# {{color 494}} [CONTROL/${ANT}/FrontEnd/WCA${N} - virtual void WCAImpl::offsetCoarseByFloog(NetSidebandMod::NetSideband, double, bool)] WCAImpl::offsetCoarseByFloog -- coarse: ${N}
# {{color 505}} [CONTROL/${ANT}/FrontEnd - void FrontEndImpl::optimizeSinglePolInternal(ReceiverBandMod::ReceiverBand, int, float&, float&)] Pol ${N} current u = ${N}[V]
# count    1193.000000
# mean      281.932942
# std        76.011737
# min        53.000000
# 25%       239.000000
# 50%       298.000000
# 75%       310.000000
# max       492.000000
# dtype: float64
# 0.018447492060120172 -3841.337488669338 4122.557202139639

# %% [markdown]
# ## Preliminary conclusion
#
# This shape don't fit well into a Gaussian or a log-normal distribution. I need to keep searching ways to make it fit to something known.

# %% [markdown]
# # Identify pulse-like shapes
# As we saw in the beginning of this doc, any dataset whose points falls in the interval *[0, PULSE_VALUE]* can be considered as individual pulses, very rapid messages that appears as a single step fast enough. This could be really the first  group of datasets to identify. Let's fix PULSE_VALUE:

# %%
PULSE_VALUE = 20  #milliseconds

# %% [markdown]
# Let's calculate the meaningful datasets now, for those datasets having at least 100 samples

# %%
MIN_NUMBER_OF_SAMPLES = 50
meaningfulPairs = {}
for (a,b) in db.pair_names():
    ipp = db._instances_per_pair[(a,b)]
    dpp = db._delays_per_pair[(a,b)]
    percen = 100.0*ipp/db.total_cases()
    
    if dpp >= MIN_NUMBER_OF_SAMPLES:    
        meaningfulPairs[(a,b)] = { 0:percen, 1:ipp,  2:dpp, 3:"---"}
        
# Add the manual classification here:

# Gaussian-Like:
for (a,b) in [ (464, 480), (465, 476), (465, 480), (466, 482), (466, 477), (468, 475), (468, 482), (469, 476), (470, 474), (470, 480), (472, 482), 
               (464, 482), (465, 473), (466, 480), (468, 478), (470, 477), (471, 478), (471, 480), (472, 477), (501, 503), (491, 495), 
               (402, 579), (492, 387), (464, 484) ]:
    meaningfulPairs[ (a, b) ][3] = "(manual) Gaussian-like"
    
# Left grouped
for (a,b) in [ (464, 469), (465, 469), (466, 468), (475, 479), (497, 498), (501, 505), (502, 504), (503, 504), (505, 506), 
               (464, 471), (465, 466), (473, 474), (476, 478), (511, 512), (505, 503) ]:
    meaningfulPairs[ (a, b) ][3] = "(manual) Left"

# Added up, or two processes coupled 
for (a,b) in [ (473, 477), (474, 476), (474, 480), (477, 483), (478, 483), (480, 484), (481, 483), (481, 484), (495, 498) ]:
    meaningfulPairs[ (a, b) ][3] = "(manual) Added"

# Curious!
for (a,b) in [ (468, 471), (493, 497), (494, 505) ]:
    meaningfulPairs[ (a, b) ][3] = "(manual) Curious"

# Any other
for (a,b) in [ (439, 487), (464, 487), (465, 495), (466, 515), (467, 400), (468, 514), (469, 498), (470, 515), (473, 498), (475, 487), (476, 486), (476, 495), (476, 497), (477, 497), (478, 486), (483, 500), (484, 402), (484, 495), (488, 402), (498, 514), 
               (580, 578), (464, 500), (469, 514), (467, 514), (471, 491), (471, 495), (474, 491), (475, 491), (478, 492), (479, 486), (497, 515), (480, 498), (469, 497), (470, 498), (479, 491), (479, 497), (476, 500), (466, 402), (477, 495), (474, 498), 
               (400, 579), (581, 580), (464, 400), (500, 514), (473, 486), (464, 491), (483, 497), (467, 402), (480, 495), (470, 495) ]:
    meaningfulPairs[ (a, b) ][3] = "(manual) Any-Other"

# %% [markdown]
# And now, let's iterate over all the datasets searching those behaving as pulse. Note that it may have been previously labelled with "Left", after manual inspection.

# %%
def multiplot(a, b, bins=10):
    v = meaningfulPairs[(a,b)]
    print "{{color %s}} %s" % (a, colors[a])
    print "{{color %s}} %s" % (b, colors[b])
    fig, ax = pyplot.subplots(1,3)
    ax[0].plot( sorted( db.getDelays(a,b) ) )
    ax[0].set_title( "Ordered %d samples for color= (%s, %s) - %s" % (v[2], a, b, v[3]) )

    ax[1].hist(  db.getDelays(a,b), orientation='horizontal', bins=bins )
    ax[1].set_title( "Histogram for color= (%s, %s) - type %s" % (a, b, v[3]) )

    ax[2].hist( remove_outliers(db.getDelays(a,b)), orientation='horizontal', bins=bins )
    ax[2].set_title( "Outliers removed (3-sigma)" )

    pyplot.show()

# %%
for (a,b) in sorted(meaningfulPairs.keys()):
    dataset = remove_outliers( db.getDelays(a,b) )
    if len(dataset) == 0:
        print "What a strange world... %s %s has no data? --- %s" % (a, b, db.getDelays(a,b) )
    if max(dataset) <= PULSE_VALUE:
        maxPoint = max(dataset)
        was = meaningfulPairs[(a,b)][3]
        meaningfulPairs[(a,b)][3] = 'Pulse'
        v = meaningfulPairs[(a,b)]
        print "(%s, %s) \t %.0f%% \t %s \t %s \t %s (was %s) \t MAX=%d" % ( a, b, v[0], v[1],  v[2], v[3], was, maxPoint )
# Out:
# (395, 400) 	 10% 	 34 	 68 	 Pulse (was ---) 	 MAX=1
# (395, 402) 	 11% 	 40 	 80 	 Pulse (was ---) 	 MAX=2
# (400, 402) 	 12% 	 43 	 81 	 Pulse (was ---) 	 MAX=1
# (464, 465) 	 100% 	 351 	 351 	 Pulse (was ---) 	 MAX=5
# (466, 467) 	 97% 	 340 	 340 	 Pulse (was ---) 	 MAX=4
# (466, 468) 	 98% 	 345 	 345 	 Pulse (was (manual) Left) 	 MAX=4
# (466, 469) 	 99% 	 348 	 348 	 Pulse (was ---) 	 MAX=4
# (466, 470) 	 100% 	 351 	 351 	 Pulse (was ---) 	 MAX=6
# (467, 468) 	 25% 	 87 	 87 	 Pulse (was ---) 	 MAX=1
# (467, 469) 	 40% 	 140 	 140 	 Pulse (was ---) 	 MAX=2
# (467, 470) 	 70% 	 246 	 246 	 Pulse (was ---) 	 MAX=3
# (468, 469) 	 28% 	 98 	 98 	 Pulse (was ---) 	 MAX=1
# (468, 470) 	 65% 	 227 	 227 	 Pulse (was ---) 	 MAX=3
# (469, 470) 	 56% 	 195 	 195 	 Pulse (was ---) 	 MAX=3
# (470, 471) 	 100% 	 351 	 351 	 Pulse (was ---) 	 MAX=19
# (471, 472) 	 100% 	 351 	 351 	 Pulse (was ---) 	 MAX=5
# (473, 474) 	 96% 	 337 	 337 	 Pulse (was (manual) Left) 	 MAX=4
# (475, 476) 	 92% 	 324 	 324 	 Pulse (was ---) 	 MAX=5
# (475, 477) 	 94% 	 330 	 330 	 Pulse (was ---) 	 MAX=5
# (475, 478) 	 95% 	 335 	 335 	 Pulse (was ---) 	 MAX=6
# (475, 479) 	 96% 	 337 	 337 	 Pulse (was (manual) Left) 	 MAX=7
# (476, 477) 	 53% 	 186 	 186 	 Pulse (was ---) 	 MAX=1
# (476, 478) 	 65% 	 228 	 228 	 Pulse (was (manual) Left) 	 MAX=2
# (476, 479) 	 76% 	 267 	 267 	 Pulse (was ---) 	 MAX=4
# (476, 480) 	 96% 	 337 	 337 	 Pulse (was ---) 	 MAX=19
# (477, 478) 	 46% 	 163 	 163 	 Pulse (was ---) 	 MAX=1
# (477, 479) 	 63% 	 222 	 222 	 Pulse (was ---) 	 MAX=4
# (477, 480) 	 96% 	 337 	 337 	 Pulse (was ---) 	 MAX=18
# (478, 479) 	 53% 	 186 	 186 	 Pulse (was ---) 	 MAX=3
# (480, 481) 	 96% 	 337 	 337 	 Pulse (was ---) 	 MAX=5
# (480, 482) 	 96% 	 337 	 337 	 Pulse (was ---) 	 MAX=11
# (481, 482) 	 96% 	 337 	 337 	 Pulse (was ---) 	 MAX=5
# (483, 484) 	 76% 	 268 	 268 	 Pulse (was ---) 	 MAX=2
# (486, 487) 	 22% 	 77 	 143 	 Pulse (was ---) 	 MAX=2
# (486, 488) 	 11% 	 38 	 73 	 Pulse (was ---) 	 MAX=2
# (486, 489) 	 14% 	 50 	 96 	 Pulse (was ---) 	 MAX=3
# (487, 489) 	 9% 	 31 	 61 	 Pulse (was ---) 	 MAX=2
# (492, 387) 	 18% 	 63 	 285 	 Pulse (was (manual) Gaussian-like) 	 MAX=19
# (492, 493) 	 17% 	 59 	 281 	 Pulse (was ---) 	 MAX=12
# (493, 387) 	 39% 	 137 	 744 	 Pulse (was ---) 	 MAX=11
# (497, 498) 	 82% 	 287 	 1218 	 Pulse (was (manual) Left) 	 MAX=6
# (502, 503) 	 21% 	 74 	 821 	 Pulse (was ---) 	 MAX=1
# (502, 504) 	 29% 	 103 	 1004 	 Pulse (was (manual) Left) 	 MAX=1
# (502, 505) 	 36% 	 127 	 1069 	 Pulse (was ---) 	 MAX=1
# (502, 506) 	 43% 	 151 	 1179 	 Pulse (was ---) 	 MAX=2
# (503, 504) 	 11% 	 38 	 371 	 Pulse (was (manual) Left) 	 MAX=1
# (503, 505) 	 21% 	 72 	 606 	 Pulse (was ---) 	 MAX=1
# (503, 506) 	 29% 	 103 	 804 	 Pulse (was ---) 	 MAX=1
# (504, 505) 	 11% 	 39 	 293 	 Pulse (was ---) 	 MAX=1
# (504, 506) 	 21% 	 74 	 580 	 Pulse (was ---) 	 MAX=1
# (505, 506) 	 12% 	 42 	 359 	 Pulse (was (manual) Left) 	 MAX=1
# (514, 515) 	 70% 	 245 	 245 	 Pulse (was ---) 	 MAX=2
# (578, 579) 	 7% 	 24 	 68 	 Pulse (was ---) 	 MAX=3
# (578, 580) 	 10% 	 36 	 106 	 Pulse (was ---) 	 MAX=4
# (578, 581) 	 15% 	 53 	 160 	 Pulse (was ---) 	 MAX=6
# (579, 580) 	 5% 	 19 	 61 	 Pulse (was ---) 	 MAX=2
# (579, 581) 	 11% 	 40 	 120 	 Pulse (was ---) 	 MAX=2
# (580, 581) 	 9% 	 31 	 90 	 Pulse (was ---) 	 MAX=2

# %% [markdown]
# ## A properties for Pulse datasets
# An interesting property appears. If the path below (N=3) are made only by pulses:

# %%
multiplot(475, 477) ; multiplot(477, 480) ; multiplot(480, 482)
# Out:
# {{color 475}} [maci::LibraryManager - maci::LibraryManager::load] Loaded '${PATH}/libTotalPowerImpl.so'.
# {{color 477}} [CONTROL/${ANT}/cppContainer-GL - ] Switched state of component CONTROL/${ANT}/TOTALPOWER: INITIALIZING -> INITIALIZED
# {{color 477}} [CONTROL/${ANT}/cppContainer-GL - ] Switched state of component CONTROL/${ANT}/TOTALPOWER: INITIALIZING -> INITIALIZED
# {{color 480}} [CONTROL/${ANT}/TOTALPOWER - ] ContainerServices::getComponentNonSticky(CONTROL/${ANT})
# {{color 480}} [CONTROL/${ANT}/TOTALPOWER - ] ContainerServices::getComponentNonSticky(CONTROL/${ANT})
# {{color 482}} [CONTROL/${ANT}/TOTALPOWER - ] ContainerServices::getComponentNonSticky(CONTROL/${ANT}/IFProc_B)

# %% [markdown]
# Then all subpaths should exists and its max values be less than N*PULSE_VALUE

# %%
#multiplot(475, 477) ; multiplot(477, 480) ; multiplot(480, 482) 
multiplot(475, 480) ; multiplot(477, 482) 
multiplot(475, 482)
# Out:
# {{color 475}} [maci::LibraryManager - maci::LibraryManager::load] Loaded '${PATH}/libTotalPowerImpl.so'.
# {{color 480}} [CONTROL/${ANT}/TOTALPOWER - ] ContainerServices::getComponentNonSticky(CONTROL/${ANT})
# {{color 477}} [CONTROL/${ANT}/cppContainer-GL - ] Switched state of component CONTROL/${ANT}/TOTALPOWER: INITIALIZING -> INITIALIZED
# {{color 482}} [CONTROL/${ANT}/TOTALPOWER - ] ContainerServices::getComponentNonSticky(CONTROL/${ANT}/IFProc_B)
# {{color 475}} [maci::LibraryManager - maci::LibraryManager::load] Loaded '${PATH}/libTotalPowerImpl.so'.
# {{color 482}} [CONTROL/${ANT}/TOTALPOWER - ] ContainerServices::getComponentNonSticky(CONTROL/${ANT}/IFProc_B)

# %% [markdown]
# # Very Long Processes
# In the same manner than with *Pulses*, the inverse can be defined case where a pair (a,b) records times so high that they are useless for the problem at hand. Let's do a quick experiment to see how many of the pairs are longer than INFINITY_THRESHOLD. In this case, the mean must be used.

# %%
INFINITY_THRESHOLD = 15 * 60 * 1000 # 15 minutes

for (a,b) in sorted(meaningfulPairs.keys()):
    dataset = remove_outliers( db.getDelays(a,b) )
    if len(dataset) == 0:
        print "What a strange world... %s %s has no data? --- %s" % (a, b, db.getDelays(a,b) )
    if  np.mean(dataset, axis=0) >= INFINITY_THRESHOLD:
        mean, minPoint, maxPoint = np.mean(dataset, axis=0), min(dataset), max(dataset)
        was = meaningfulPairs[(a,b)][3]
        meaningfulPairs[(a,b)][3] = 'Infinite'
        v = meaningfulPairs[(a,b)]
        print "(%s, %s) \t %.0f%% \t %s \t %s \t %s (was %s) \t MEAN/MIN/MAX=%d/%d/%d" % ( a, b, v[0], v[1],  v[2], v[3], was, mean, minPoint, maxPoint )
# Out:
# (400, 514) 	 26% 	 92 	 92 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1840810/118777/5346615
# (400, 515) 	 26% 	 92 	 92 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1840810/118777/5346615
# (402, 514) 	 26% 	 92 	 92 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1840809/118776/5346615
# (402, 515) 	 26% 	 92 	 92 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1840810/118776/5346615
# (464, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383302/7969/6185663
# (464, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383303/7970/6185664
# (465, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383299/7968/6185662
# (465, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383300/7969/6185663
# (466, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383249/7954/6185648
# (466, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383250/7955/6185649
# (467, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383248/7953/6185647
# (467, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383248/7954/6185648
# (468, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383248/7952/6185647
# (468, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383248/7953/6185648
# (469, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383247/7952/6185647
# (469, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383248/7953/6185648
# (470, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383247/7952/6185646
# (470, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383247/7953/6185647
# (471, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383239/7942/6185632
# (471, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383239/7943/6185633
# (472, 514) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383237/7941/6185631
# (472, 515) 	 97% 	 339 	 339 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1383237/7942/6185632
# (473, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417877/10074/6167085
# (473, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417878/10075/6167086
# (474, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417875/10073/6167083
# (474, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417876/10074/6167084
# (475, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417686/9866/6167006
# (475, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417686/9868/6167007
# (476, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417684/9864/6167004
# (476, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417685/9866/6167005
# (477, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417684/9863/6167004
# (477, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417684/9865/6167005
# (478, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417683/9862/6167004
# (478, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417684/9864/6167005
# (479, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417683/9860/6167004
# (479, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417683/9862/6167005
# (480, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417675/9838/6167000
# (480, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417676/9840/6167001
# (481, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417673/9834/6166999
# (481, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417674/9836/6167000
# (482, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417671/9832/6166998
# (482, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1417672/9834/6166999
# (483, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1416396/7495/6166852
# (483, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1416397/7497/6166853
# (484, 514) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1416396/7495/6166851
# (484, 515) 	 93% 	 325 	 325 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1416396/7497/6166852
# (486, 514) 	 29% 	 103 	 103 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1649859/38928/5346615
# (486, 515) 	 29% 	 103 	 103 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1649860/38928/5346615
# (487, 514) 	 29% 	 103 	 103 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1649859/38928/5346615
# (487, 515) 	 29% 	 103 	 103 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1649859/38928/5346615
# (491, 514) 	 31% 	 108 	 108 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1061876/99607/5345248
# (491, 515) 	 31% 	 108 	 108 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=1061876/99607/5345248
# (492, 514) 	 34% 	 121 	 121 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=966210/68076/5345193
# (492, 515) 	 34% 	 121 	 121 	 Infinite (was Infinite) 	 MEAN/MIN/MAX=966211/68077/5345193

# %% [markdown]
# Some assorted examples of these, basically, useless pairs:

# %%
multiplot(464, 515, bins=30)
multiplot(484, 515, bins=30)
# Out:
# {{color 464}} [maci::LibraryManager - maci::LibraryManager::load] Request to load 'AntInterferometryController'.
# {{color 515}} [CONTROL/${ANT}/cppContainer-GL - ] Switched state of component CONTROL/${ANT}/AntInterferometryController: DESTROYING -> DEFUNCT
# {{color 484}} [CONTROL/${ANT}/IFProc_B - beginDataAcquisition] Data acquisition activated.
# {{color 515}} [CONTROL/${ANT}/cppContainer-GL - ] Switched state of component CONTROL/${ANT}/AntInterferometryController: DESTROYING -> DEFUNCT

# %% [markdown]
# # Leftist distributions
#
# These distributions of delays are grouped mainly at lower numbers. Examples are (464, 469), (465, 469) and candidates but most probable false positives: (400, 579), (505, 503).

# %%
#multiplot(464, 465, bins=30)
multiplot(464, 469, bins=30)
multiplot(465, 469, bins=30)

# Conjeture
# If (a,b) is X-type and (a,c) is Pulse, => (c,b) is X-type

multiplot(505, 503, bins=30)
# Out:
# {{color 464}} [maci::LibraryManager - maci::LibraryManager::load] Request to load 'AntInterferometryController'.
# {{color 469}} [CONTROL/${ANT}/cppContainer-GL - ] Switched state of component CONTROL/${ANT}/AntInterferometryController: INITIALIZED -> OPERATIONAL
# {{color 465}} [maci::LibraryManager - maci::LibraryManager::load] Full path '${PATH}/libAntInterferometryController.so'
# {{color 469}} [CONTROL/${ANT}/cppContainer-GL - ] Switched state of component CONTROL/${ANT}/AntInterferometryController: INITIALIZED -> OPERATIONAL
# {{color 505}} [CONTROL/${ANT}/FrontEnd - void FrontEndImpl::optimizeSinglePolInternal(ReceiverBandMod::ReceiverBand, int, float&, float&)] Pol ${N} current u = ${N}[V]
# {{color 503}} [CONTROL/${ANT}/FrontEnd - void FrontEndImpl::optimizeSinglePolInternal(ReceiverBandMod::ReceiverBand, int, float&, float&)] Pol${N}: ijc=${N},ij${N}=${N},ij${N}=${N}

# %% [markdown]
# # Identified pairs as artifacts of the method
# The event coloured as 512:
#
# ```[CONTROL/${ANT}/cppContainer-GL - void PositionStreamConsumer::processData(Control::MountStatusData)] At ${N}:${N}:${N} got the last needed data with a timestamp of ${N}:${N}:${N}. The delay is ${N} seconds.
# ```
#
# Is a process that is randomly signaled to measure data. Therefore, in theory the pairs (511, 512) (490, 512) should not carry any valuable information.
#
# Ths is true for (510, 512) and (511, 512), however there seems to be a specific behavior between (490, 512). Probably the origin of the process the produces "Parking the Calibration Device" is related with the origin of MountStatusData counter. This case is remarkable because it can origin new information not available previously.

# %%
multiplot(490, 512, bins=30)
multiplot(510, 512, bins=30)
multiplot(511, 512, bins=30)
# Out:
# {{color 490}} [CONTROL/${ANT}/FrontEnd/ACD - void ACDImpl::setCalibrationDeviceBandInternal(CalibrationDeviceMod::CalibrationDevice, ReceiverBandMod::ReceiverBand)] Parking the Calibration Device
# {{color 512}} [CONTROL/${ANT}/cppContainer-GL - void PositionStreamConsumer::processData(Control::MountStatusData)] At ${N}:${N}:${N} got the last needed data with a timestamp of ${N}:${N}:${N}. The delay is ${N} seconds.
# {{color 510}} [CONTROL/${ANT}/FrontEnd/IFSwitch - ] ContainerServices::getComponentNonSticky(CONTROL/${ANT}/IFProc_A)
# {{color 512}} [CONTROL/${ANT}/cppContainer-GL - void PositionStreamConsumer::processData(Control::MountStatusData)] At ${N}:${N}:${N} got the last needed data with a timestamp of ${N}:${N}:${N}. The delay is ${N} seconds.
# {{color 511}} [CONTROL/${ANT}/FrontEnd/IFSwitch - ] ContainerServices::getComponentNonSticky(CONTROL/${ANT}/IFProc_B)
# {{color 512}} [CONTROL/${ANT}/cppContainer-GL - void PositionStreamConsumer::processData(Control::MountStatusData)] At ${N}:${N}:${N} got the last needed data with a timestamp of ${N}:${N}:${N}. The delay is ${N} seconds.

# %% [markdown]
# A properly done analysis should classify the pair (490, 512) as "Composed" with 2 components.

# %% [markdown]
# ## Scalonated dataset

# %%
multiplot(493,494, bins=30)
multiplot(494,501, bins=30)
# Out:
# {{color 493}} [CONTROL/${ANT}/FrontEnd - void FrontEndImpl::lockFrontEndInternal(Control::FrontEnd::SubscanInformation, bool, bool)] Setting band ${N} park frequency to ${N}
# {{color 494}} [CONTROL/${ANT}/FrontEnd/WCA${N} - virtual void WCAImpl::offsetCoarseByFloog(NetSidebandMod::NetSideband, double, bool)] WCAImpl::offsetCoarseByFloog -- coarse: ${N}
# {{color 494}} [CONTROL/${ANT}/FrontEnd/WCA${N} - virtual void WCAImpl::offsetCoarseByFloog(NetSidebandMod::NetSideband, double, bool)] WCAImpl::offsetCoarseByFloog -- coarse: ${N}
# {{color 501}} [CONTROL/${ANT}/FrontEnd - void FrontEndImpl::optimizeSinglePolInternal(ReceiverBandMod::ReceiverBand, int, float&, float&)] Pol${N}: Target ij=${N}
